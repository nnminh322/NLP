# %%
import pandas as pd
from datetime import datetime

# %%
# Imported from ChatGPT and manuel analysis

text = """
| Symbol | Company Name                    | Sector             | Industry                        | Headquarters           | Date Added | CIK     | Founded |
|--------|---------------------------------|--------------------|----------------------------------|------------------------|------------|---------|---------|
| UAA    | Under Armour, Inc.              | Consumer Discretionary | Apparel, Accessories, & Luxury | Baltimore, MD          | 2016       | 1336917 | 1996    |
| ETFC   | E*TRADE Financial Corporation   | Financials          | Investment Banking & Brokerage  | Arlington, VA          | 2004       | 1015780 | 1982    |
| ALXN   | Alexion Pharmaceuticals, Inc.   | Healthcare          | Biotechnology                  | Boston, MA             | 2012       | 899866  | 1992    |
| ABMD   | Abiomed, Inc.                   | Healthcare          | Medical Devices                | Danvers, MA            | 2018       | 815094  | 1981    |
| FBHS   | Fortune Brands Home & Security  | Industrials         | Building Products              | Deerfield, IL          | 2011       | 1519751 | 2011    |
| BLL    | Ball Corporation                | Materials           | Containers & Packaging         | Westminster, CO        | 1970       | 9389    | 1880    |
| ILMN   | Illumina, Inc.                  | Healthcare          | Life Sciences Tools & Services | San Diego, CA          | 2015       | 1110803 | 1998    |
| UA     | Under Armour, Inc.              | Consumer Discretionary | Apparel, Accessories, & Luxury | Baltimore, MD          | 2016       | 1336917 | 1996    |
| VNO    | Vornado Realty Trust            | Real Estate         | Real Estate Investment Trusts  | New York, NY           | 2001       | 899689  | 1982    |
| DISCA  | Discovery, Inc.                 | Communication Services | Broadcasting                | New York, NY           | 2014       | 1437107 | 1985    |
| DRE    | Duke Realty Corporation         | Real Estate         | Industrial REITs               | Indianapolis, IN       | 2004       | 783280  | 1972    |
| SLG    | SL Green Realty Corp.           | Real Estate         | Office REITs                   | New York, NY           | 2004       | 1040971 | 1997    |
| ABC    | AmerisourceBergen Corporation   | Healthcare          | Healthcare Distributors        | Conshohocken, PA       | 2001       | 1140859 | 2001    |
| WRK    | WestRock Company                | Materials           | Paper & Forest Products        | Atlanta, GA            | 2015       | 1732845 | 1953    |
| DISH   | DISH Network Corporation        | Communication Services | Cable & Satellite            | Englewood, CO          | 2004       | 1001082 | 1980    |
| DXC    | DXC Technology Co.              | Information Technology | IT Services                  | Ashburn, VA            | 2017       | 1688568 | 2017    |
| HFC    | HollyFrontier Corporation        | Energy              | Oil & Gas Refining & Marketing  | Dallas, TX             | 2018       | 48039   | 1947    |
| AAP    | Advance Auto Parts, Inc.        | Consumer Discretionary | Specialty Retail              | Raleigh, NC            | 2015       | 1158449 | 1932    |
| RE     | Everest Re Group, Ltd.          | Financials          | Reinsurance                    | Hamilton, Bermuda      | 2010       | 1095073 | 1973    |
"""
lines = text.split("\n")
header = lines[1].strip("|").split("|")

data = [] 

# Loop through lines starting from 2
for line in lines[2:]:
    
    # Break once we hit an empty line
    if not line.strip():
        break
        
    cols = line.strip("|").split("|")
    row = dict(zip(header, cols))
    data.append(row)
    
df_test = pd.DataFrame(data).iloc[1:len(data)]
df_test = df_test.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_test.columns = [col.strip() for col in header]
df_test.to_csv("constituents_missing.csv", index=False)

# %%
df_missing = pd.read_csv("constituents_missing.csv")
df = pd.read_csv("~/genial4kmu/data/pixiu/constituents.csv")
df_missing.columns = df.columns
df_missing["Date added"] = df_missing["Date added"].apply(lambda x: datetime.strptime(str(x), "%Y").strftime("%Y-%m-%d"))
pd.concat([df, df_missing]).to_csv("constituents_all.csv", index=False)
